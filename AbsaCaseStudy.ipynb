# %%
import pandas as pd 
import numpy as np

df=pd.read_csv("./12AprMay2020.csv",error_bad_lines=False)
# Out:
# b'Skipping line 11798: expected 41 fields, saw 48\nSkipping line 12162: expected 41 fields, saw 48\nSkipping line 12235: expected 41 fields, saw 48\nSkipping line 13081: expected 41 fields, saw 48\nSkipping line 13853: expected 41 fields, saw 48\nSkipping line 14590: expected 41 fields, saw 48\nSkipping line 15519: expected 41 fields, saw 48\nSkipping line 15564: expected 41 fields, saw 48\nSkipping line 15622: expected 41 fields, saw 48\n'
# ...

# %%
df.columns
# Out:
# Index(['id', 'uri', 'link', 'title', 'extract', 'published',
#        'visibility.label', 'authorId', 'authorName', 'authorHandle',
#        'authorHandleId', 'authorPictureLink', 'authorProfileLink', 'authorBio',
#        'authorLocation', 'authorTimezone', 'replyToUri', 'replyToId',
#        'reshareOfUri', 'reshareOfId', 'toId', 'toName', 'toHandle',
#        'toHandleId', 'postExtract', 'relevancy', 'relevancyVerified',
#        'sentiment', 'sentimentVerified', 'crowdVerified', 'pickedUp',
#        'city.name', 'region.name', 'country.name', 'language.name',
#        'category.label', 'gender.label', 'race.label', 'engagement', 'OTS',
#        'tags'],
#       dtype='object')

# %%
df.index  #How many rows do we have
# Out:
# RangeIndex(start=0, stop=66264, step=1)

# %%
#The body of the data is represented by ;
#If you like dealing with arrays and mostly use phython
df.values
# Out:
# array([['150335-1738949',
#         'http://twitter.com/x/status/1267213112358383618',
#         'http://twitter.com/WestoverAllan/statuses/1267213112358383618',
#         ..., nan, 7.0,
#         'segment:Non-CX post tag:Twitter tag:Overall conversation segment:Non-conduct post'],
#        ['150335-1738890',
#         'http://twitter.com/x/status/1267212607519371267',
#         'http://twitter.com/LKMamabolo/statuses/1267212607519371267',
#         ..., nan, 1751.0,
#         'tag:Engage - received tag:Engage - ticketed tag:Twitter tag:Overall conversation'],
#        ['150335-1738889',
#         'http://twitter.com/x/status/1267212001819975680',
#         'http://twitter.com/HarrisMolefi/statuses/1267212001819975680',
#         ..., nan, 363.0,
#         'crowd:duplicate segment:Non-conduct reshare tag:Twitter tag:Overall conversation segment:Non-CX reshare'],
#        ...,
#        ['150335-1554217',
#         'http://twitter.com/x/status/1245115283485995011',
# ...

# %%
df.shape
# Out:
# (66264, 41)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66264 entries, 0 to 66263
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 66264 non-null  object
#  1   uri                66264 non-null  object
#  2   link               66264 non-null  object
#  3   title              0 non-null      float64
#  4   extract            66264 non-null  object
#  5   published          66264 non-null  object
#  6   visibility.label   11809 non-null  object
#  7   authorId           62131 non-null  object
#  8   authorName         62131 non-null  object
#  9   authorHandle       62131 non-null  object
#  10  authorHandleId     62131 non-null  float64
#  11  authorPictureLink  62131 non-null  object
#  12  authorProfileLink  62131 non-null  object
#  13  authorBio          54389 non-null  object
#  14  authorLocation     50546 non-null  object
#  15  authorTimezone     0 non-null      float64
# ...

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
df["uri"].head()
# Out:
# 0    http://twitter.com/x/status/1267213112358383618
# 1    http://twitter.com/x/status/1267212607519371267
# 2    http://twitter.com/x/status/1267212001819975680
# 3    http://twitter.com/x/status/1267211122727403531
# 4    http://twitter.com/x/status/1267209762556575744
# Name: uri, dtype: object

# %%
df.head()
# Out:
#                id  ...                                               tags
# 0  150335-1738949  ...  segment:Non-CX post tag:Twitter tag:Overall co...
# 1  150335-1738890  ...  tag:Engage - received tag:Engage - ticketed ta...
# 2  150335-1738889  ...  crowd:duplicate segment:Non-conduct reshare ta...
# 3  150335-1738888  ...  crowd:duplicate segment:Non-conduct reshare ta...
# 4  150335-1738948  ...  crowd:duplicate segment:Non-conduct reshare ta...
#
# [5 rows x 41 columns]

# %%
df.loc[3]  #looking at what is printed as pos. at 2,not index 2
# Out:
# id                                                      150335-1738888
# uri                    http://twitter.com/x/status/1267211122727403531
# link                   http://twitter.com/x/status/1267211122727403531
# title                                                              NaN
# extract                                (this mention has been deleted)
# published                                          2020-05-31 23:47:29
# visibility.label                                                   NaN
# authorId                                                           NaN
# authorName                                                         NaN
# authorHandle                                                       NaN
# authorHandleId                                                     NaN
# authorPictureLink                                                  NaN
# authorProfileLink                                                  NaN
# ...

# %%
df.loc[[3,6]]
# Out:
#                id  ...                                               tags
# 3  150335-1738888  ...  crowd:duplicate segment:Non-conduct reshare ta...
# 6  150335-1738886  ...  crowd:duplicate segment:Non-conduct reshare ta...
#
# [2 rows x 41 columns]

# %%
#using index , use iloc

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66264 entries, 0 to 66263
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 66264 non-null  object
#  1   uri                66264 non-null  object
#  2   link               66264 non-null  object
#  3   title              0 non-null      float64
#  4   extract            66264 non-null  object
#  5   published          66264 non-null  object
#  6   visibility.label   11809 non-null  object
#  7   authorId           62131 non-null  object
#  8   authorName         62131 non-null  object
#  9   authorHandle       62131 non-null  object
#  10  authorHandleId     62131 non-null  float64
#  11  authorPictureLink  62131 non-null  object
#  12  authorProfileLink  62131 non-null  object
#  13  authorBio          54389 non-null  object
#  14  authorLocation     50546 non-null  object
#  15  authorTimezone     0 non-null      float64
# ...

# %%
#How about when we want to subset our data 
#Loc and iloc are the inbuild function you want to be using
#How do we subset both rows and columns 
 
subset=df.loc[:,['uri','link','relevancy']]
subset.head()
# Out:
#                                                uri  ...   relevancy
# 0  http://twitter.com/x/status/1267213112358383618  ...    RELEVANT
# 1  http://twitter.com/x/status/1267212607519371267  ...    RELEVANT
# 2  http://twitter.com/x/status/1267212001819975680  ...    RELEVANT
# 3  http://twitter.com/x/status/1267211122727403531  ...  IRRELEVANT
# 4  http://twitter.com/x/status/1267209762556575744  ...    RELEVANT
#
# [5 rows x 3 columns]

# %%
#We want the rows where the comments are relavant to our brand 
#Where relevancy=RELEVANT 
#how do we do that?

df.loc[df['relevancy']=='RELEVANT',['uri','link','relevancy']]
# Out:
#                                                    uri  ... relevancy
# 0      http://twitter.com/x/status/1267213112358383618  ...  RELEVANT
# 1      http://twitter.com/x/status/1267212607519371267  ...  RELEVANT
# 2      http://twitter.com/x/status/1267212001819975680  ...  RELEVANT
# 4      http://twitter.com/x/status/1267209762556575744  ...  RELEVANT
# 5      http://twitter.com/x/status/1267208331761942531  ...  RELEVANT
# ...                                                ...  ...       ...
# 66259  http://twitter.com/x/status/1245116208111931392  ...  RELEVANT
# 66260  http://twitter.com/x/status/1245116107092111360  ...  RELEVANT
# 66261  http://twitter.com/x/status/1245115283485995011  ...  RELEVANT
# 66262  http://twitter.com/x/status/1245114494835134471  ...  RELEVANT
# 66263  http://twitter.com/x/status/1245109321756786695  ...  RELEVANT
#
# [59402 rows x 3 columns]
